# %% [markdown]
# ## Pizza Place Sales
# A year's worth of sales from a fictitious pizza place, including the date and time of each order and the pizzas served, with additional details on the type, size, quantity, price, and ingredients.
#
# ### Recommended Analysis
# - What is the total revenue/sales?
# - Find the total quantity sold.
# - Find the total orders.
# - How many pizza types do they sell?
# - Find the average price of the pizzas.
# - What are the peak hours of sales?
# - Find the total sales made on each day of the week. Which day of the week is when sales are made the most?
# - Find the top 5 bestselling pizzas.
# - Find the sales made in each month. Any trend noticeable?
# - Are there pizza types that are not doing well on the menu?

# %%
# Import libraries for analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import warnings
warnings.filterwarnings("ignore")

# %%
# Import orders data
path_1 = r"C:\Users\Etebom\Downloads\TC\T3\Pizza_Place_Sales\Pizza-Place-Sales\dataset\Pizza+Place+Sales\pizza_sales\orders.csv"
df1 = pd.read_csv(path_1)

# Get a snapshot of df1
df1.head()
# Out:
#    order_id        date      time
# 0         1  2015-01-01  11:38:36
# 1         2  2015-01-01  11:57:40
# 2         3  2015-01-01  12:12:28
# 3         4  2015-01-01  12:16:31
# 4         5  2015-01-01  12:21:30

# %%
# Assess df1
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21350 entries, 0 to 21349
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   order_id  21350 non-null  int64
#  1   date      21350 non-null  object
#  2   time      21350 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 500.5+ KB

# %%
# Import order_details data
path_2 = r"C:\Users\Etebom\Downloads\TC\T3\Pizza_Place_Sales\Pizza-Place-Sales\dataset\Pizza+Place+Sales\pizza_sales\order_details.csv"
df2 = pd.read_csv(path_2)

## Get a snapshot of df2
df2.head()
# Out:
#    order_details_id  order_id       pizza_id  quantity
# 0                 1         1     hawaiian_m         1
# 1                 2         2  classic_dlx_m         1
# 2                 3         2  five_cheese_l         1
# 3                 4         2    ital_supr_l         1
# 4                 5         2     mexicana_m         1

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  int64
#  1   order_id          48620 non-null  int64
#  2   pizza_id          48620 non-null  object
#  3   quantity          48620 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
# Import pizza_types data
path_3 = r"C:\Users\Etebom\Downloads\TC\T3\Pizza_Place_Sales\Pizza-Place-Sales\dataset\Pizza+Place+Sales\pizza_sales\pizza_types.csv"
df3 = pd.read_csv(path_3, encoding="cp1252")

# Get a snapshot of df3
df3.head()
# Out:
#   pizza_type_id                          name category  \
# 0       bbq_ckn    The Barbecue Chicken Pizza  Chicken
# 1      cali_ckn  The California Chicken Pizza  Chicken
# 2   ckn_alfredo     The Chicken Alfredo Pizza  Chicken
# 3     ckn_pesto       The Chicken Pesto Pizza  Chicken
# 4    southw_ckn   The Southwest Chicken Pizza  Chicken
#
#                                          ingredients
# 0  Barbecued Chicken, Red Peppers, Green Peppers,...
# 1  Chicken, Artichoke, Spinach, Garlic, Jalapeno ...
# 2  Chicken, Red Onions, Red Peppers, Mushrooms, A...
# 3  Chicken, Tomatoes, Red Peppers, Spinach, Garli...
# 4  Chicken, Tomatoes, Red Peppers, Red Onions, Ja...

# %%
# Assess df3
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pizza_type_id  32 non-null     object
#  1   name           32 non-null     object
#  2   category       32 non-null     object
#  3   ingredients    32 non-null     object
# dtypes: object(4)
# memory usage: 1.1+ KB

# %%
# Import pizzas data
path_4 = r"C:\Users\Etebom\Downloads\TC\T3\Pizza_Place_Sales\Pizza-Place-Sales\dataset\Pizza+Place+Sales\pizza_sales\pizzas.csv"
df4 = pd.read_csv(path_4)

# Get a snapshot of df4
df4.head()
# Out:
#      pizza_id pizza_type_id size  price
# 0   bbq_ckn_s       bbq_ckn    S  12.75
# 1   bbq_ckn_m       bbq_ckn    M  16.75
# 2   bbq_ckn_l       bbq_ckn    L  20.75
# 3  cali_ckn_s      cali_ckn    S  12.75
# 4  cali_ckn_m      cali_ckn    M  16.75

# %%
# Assess df4
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pizza_id       96 non-null     object
#  1   pizza_type_id  96 non-null     object
#  2   size           96 non-null     object
#  3   price          96 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 3.1+ KB

# %%
# Join df1 & df2 dataframes
df = pd.merge(df1, df2, on="order_id", how="inner")

# %%
# Join df & df4 dataframes
df = pd.merge(df, df4, on="pizza_id", how="inner")

# %%
# Join df & df3 dataframes
df = pd.merge(df, df3, on="pizza_type_id", how="inner")

# %%
# Get a snapshot of the new dataframe df
df.head()
# Out:
#    order_id        date      time  order_details_id       pizza_id  quantity  \
# 0         1  2015-01-01  11:38:36                 1     hawaiian_m         1
# 1         2  2015-01-01  11:57:40                 2  classic_dlx_m         1
# 2         2  2015-01-01  11:57:40                 3  five_cheese_l         1
# 3         2  2015-01-01  11:57:40                 4    ital_supr_l         1
# 4         2  2015-01-01  11:57:40                 5     mexicana_m         1
#
#   pizza_type_id size  price                       name category  \
# 0      hawaiian    M  13.25         The Hawaiian Pizza  Classic
# 1   classic_dlx    M  16.00   The Classic Deluxe Pizza  Classic
# 2   five_cheese    L  18.50      The Five Cheese Pizza   Veggie
# 3     ital_supr    L  20.75  The Italian Supreme Pizza  Supreme
# 4      mexicana    M  16.00         The Mexicana Pizza   Veggie
#
#                                          ingredients
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...

# %%
# Assess df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          48620 non-null  int64
#  1   date              48620 non-null  object
#  2   time              48620 non-null  object
#  3   order_details_id  48620 non-null  int64
#  4   pizza_id          48620 non-null  object
#  5   quantity          48620 non-null  int64
#  6   pizza_type_id     48620 non-null  object
#  7   size              48620 non-null  object
#  8   price             48620 non-null  float64
#  9   name              48620 non-null  object
#  10  category          48620 non-null  object
#  11  ingredients       48620 non-null  object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 4.5+ MB

# %%
# Create a wrangle function
def wrangle(df):
    # Convert date column to DateTime data type
    df["date"] = pd.to_datetime(df["date"])

    # Create month column based on date
    df["month"] = df["date"].dt.month_name()

    # Create day_of_week column based on date
    df["day_of_week"] = df["date"].dt.day_name()
    
    # Create hour column based on time
    df["hour"] = pd.to_datetime(df["time"]).dt.hour


    # Create a sales column
    df["sales"] = df["quantity"] * df["price"]
    
    return df

# %%
# Apply wrangle function on df
df = wrangle(df)
df.head()
# Out:
#    order_id       date      time  order_details_id       pizza_id  quantity  \
# 0         1 2015-01-01  11:38:36                 1     hawaiian_m         1
# 1         2 2015-01-01  11:57:40                 2  classic_dlx_m         1
# 2         2 2015-01-01  11:57:40                 3  five_cheese_l         1
# 3         2 2015-01-01  11:57:40                 4    ital_supr_l         1
# 4         2 2015-01-01  11:57:40                 5     mexicana_m         1
#
#   pizza_type_id size  price                       name category  \
# 0      hawaiian    M  13.25         The Hawaiian Pizza  Classic
# 1   classic_dlx    M  16.00   The Classic Deluxe Pizza  Classic
# 2   five_cheese    L  18.50      The Five Cheese Pizza   Veggie
# 3     ital_supr    L  20.75  The Italian Supreme Pizza  Supreme
# 4      mexicana    M  16.00         The Mexicana Pizza   Veggie
#
#                                          ingredients    month day_of_week  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese  January    Thursday
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...  January    Thursday
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...  January    Thursday
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...  January    Thursday
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...  January    Thursday
#
#    hour  sales
# 0    11  13.25
# 1    11  16.00
# 2    11  18.50
# 3    11  20.75
# 4    11  16.00

# %% [markdown]
# ### What is the total revenue/sales?

# %%
# Calculate Total Sales
ts = df["sales"].sum()
print(f"The total sales is ${ts:,}.")
# Out:
# The total sales is $817,860.05.

# %% [markdown]
# ### Find the total quantity sold.

# %%
# Calculate total quantity sold
tqs = df["quantity"].sum()
print(f"The total quantity sold is {tqs:,} units.")
# Out:
# The total quantity sold is 49,574 units.

# %% [markdown]
# ### Find the total orders.

# %%
# Calculate the total orders
to = df["order_id"].nunique()
print(f"The total orders made is {to:,}.")
# Out:
# The total orders made is 21,350.

# %% [markdown]
# ### How many pizza types do they sell?

# %%
# Calculate number of pizza types
pt = df["name"].nunique()
print(f"They sell {pt} types of pizza.")
# Out:
# They sell 32 types of pizza.

# %% [markdown]
# ### Find the average price of the pizzas.

# %%
ap = df4["price"].mean()
print(f"The average price of pizzas is ${ap:,.2f}.")
# Out:
# The average price of pizzas is $16.44.

# %% [markdown]
# ### What are the peak hours of sales?

# %%
ph = df.groupby(["hour"])["sales"].sum().sort_values(ascending=False).reset_index()
print(f"The peak hours of sales are {ph['hour'][0]}:00 and {ph['hour'][1]}:00.")
# Out:
# The peak hours of sales are 12:00 and 13:00.

# %%
# Scatterplot of Daily sales Trend
sns.scatterplot(data=ph, x="hour", y="sales")
plt.title("Daily sales Trend")
plt.xlabel("Hour")
plt.ylabel("Total Sales")
plt.show();

# %% [markdown]
# ### Find the total sales made on each day of the week. Which day of the week is when sales are made the most?

# %%
# MAke day_of_week ordered and categorical
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
df["day_of_week"] = pd.Categorical(df["day_of_week"], categories=days, ordered=True)

# %%
# Calculate days with highest sales
dows = df.groupby("day_of_week")["sales"].sum().sort_values(ascending=False).reset_index()
print(f"{dows['day_of_week'][0]} is the day of week when sales are made the most.")
# Out:
# Friday is the day of week when sales are made the most.

# %%
# Visualize Daily sales Trend
sns.lineplot(data=dows, x="day_of_week", y="sales", marker="o")
plt.title("Daily sales Trend")
plt.xlabel("Day of Week")
plt.ylabel("Total Sales")
plt.show();

# %% [markdown]
# ### Find the top 5 bestselling pizzas.

# %%
bsp = df.groupby("name")["sales"].sum().sort_values(ascending=False).reset_index()
print(f"The top 5 bestselling pizzas are \n- {bsp['name'][0]}, \n- {bsp['name'][1]}, \n- {bsp['name'][2]}, \n- {bsp['name'][3]}, and \n- {bsp['name'][4]}.")
# Out:
# The top 5 bestselling pizzas are
# - The Thai Chicken Pizza,
# - The Barbecue Chicken Pizza,
# - The California Chicken Pizza,
# - The Classic Deluxe Pizza, and
# - The Spicy Italian Pizza.

# %%
sns.barplot(data=bsp.head(), x="name", y="sales")
plt.title("Sales by Pizza Type")
plt.xlabel("Pizza Type")
plt.xticks(rotation=90)
plt.ylabel("Total Sales")
plt.show();

# %% [markdown]
# ### Find the sales made in each month. Any trend noticeable?

# %%
months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
df["month"] = pd.Categorical(df["month"], categories=months, ordered=True)

# %%
spm = df.groupby("month")["sales"].sum().reset_index()
spm
# Out:
#         month     sales
# 0     January  69793.30
# 1    February  65159.60
# 2       March  70397.10
# 3       April  68736.80
# 4         May  71402.75
# 5        June  68230.20
# 6        July  72557.90
# 7      August  68278.25
# 8   September  64180.05
# 9     October  64027.60
# 10   November  70395.35
# 11   December  64701.15

# %%
sns.barplot(data=spm, x="sales",  y="month")
plt.title("Monthly Pizza Sales Trend")
plt.xlabel("Total Sales")
plt.xticks(rotation=90)
plt.ylabel("Month")
plt.show();

# %% [markdown]
# May, July, and November are holiday months with Independence Day on July 4th.
# PEople seem to spend more during festive months than in other months, but it seems that pizza sales are not in high demand
# during Thanksgiving and Christmas since those are times when people returto theirfamilies which means that home-cooked
# meals replace some demand for pizza at such times.

# %% [markdown]
# ### Are there pizza types that are not doing well on the menu?

# %%
# Least performing pizza types
print(f"The top 5 least selling pizzas are \n- {bsp['name'][27]}, \n- {bsp['name'][28]}, \n- {bsp['name'][29]}, \n- {bsp['name'][30]}, and \n- {bsp['name'][31]}.")
# Out:
# The top 5 least selling pizzas are
# - The Spinach Pesto Pizza,
# - The Mediterranean Pizza,
# - The Spinach Supreme Pizza,
# - The Green Garden Pizza, and
# - The Brie Carre Pizza.

# %%
# Barplot of least performing pizza types
sns.barplot(data=bsp.tail(), x="name", y="sales")
plt.title("Sales by Pizza Type")
plt.xlabel("Pizza Type")
plt.xticks(rotation=90)
plt.ylabel("Total Sales")
plt.show();

# %%
sns.histplot(df["sales"], kde=True)
plt.show();

# %%
ax = sns.histplot(df["sales"], kde=True)

hist_df = pd.DataFrame({
    "Bin Start": [p.get_x() for p in ax.patches],
    "Bin End": [p.get_x() + p.get_width() for p in ax.patches],
    "Count": [int(p.get_height()) for p in ax.patches]
})

hist_df.sort_values("Count", ascending=False)
# Out:
#     Bin Start    Bin End  Count
# 25  20.335260  20.758671  10456
# 5   11.867052  12.290462   6275
# 15  16.101156  16.524566   5064
# 14  15.677746  16.101156   4428
# 16  16.524566  16.947977   4211
# ..        ...        ...    ...
# 29  22.028902  22.452312      0
# 85  45.739884  46.163295      0
# 84  45.316474  45.739884      0
# 83  44.893064  45.316474      0
# 86  46.163295  46.586705      0
#
# [173 rows x 3 columns]

# %%
df["sales"].value_counts()
# Out:
# sales
# 20.75    8485
# 12.00    5465
# 16.00    4428
# 16.75    4211
# 16.50    3970
# 12.50    3278
# 20.25    2971
# 12.75    2485
# 20.50    1971
# 18.50    1310
# 17.95    1230
# 16.25    1094
# 10.50     982
# 12.25     810
# 9.75      727
# 15.25     696
# 14.75     568
# 11.00     562
# 25.50     558
# 23.65     470
# 13.25     463
# 14.50     385
# 17.50     378
# 21.00     209
# 41.50     195
# 24.00     128
# 33.50      80
# 33.00      69
# 40.50      61
# 37.00      48
# 25.00      48
# 32.00      44
# 35.90      43
# 35.95      28
# 41.00      26
# 24.50      20
# 32.50      18
# 30.50      16
# 19.50      12
# 47.30      10
# 26.50      10
# 29.50       9
# 51.00       8
# 22.00       8
# 29.00       6
# 36.00       5
# 62.25       4
# 48.00       4
# 35.00       3
# 50.25       3
# 48.75       2
# 37.50       2
# 83.00       1
# 61.50       1
# 49.50       1
# 55.50       1
# Name: count, dtype: int64

# %%
plt.bar(df["sales"])
plt.xticks(rotation=90);

# %%
vc = df["sales"].value_counts().head(20)
plt.bar(vc.index.astype(str), vc.values)
plt.xticks(rotation=90);

# %% [markdown]
# The histogram above shows the distribution of sales values.
# The highest peak  is close around $20.
# The next seems to be around $12.

# %%
df["sales"].describe().round(2)
# Out:
# count    48620.00
# mean        16.82
# std          4.44
# min          9.75
# 25%         12.75
# 50%         16.50
# 75%         20.50
# max         83.00
# Name: sales, dtype: float64

# %%
sns.boxplot(df["sales"]);

# %%
(df[df["sales"] == 20.75]
    .groupby(["name", "size"])
    .agg(
        orders=("order_id", "nunique"),
        quantity=("quantity", "sum")
    )
    .sort_values("orders", ascending=False)
)
# Out:
#                                        orders  quantity
# name                             size
# The Thai Chicken Pizza           L       1321      1321
# The Spicy Italian Pizza          L       1068      1068
# The Southwest Chicken Pizza      L        970       970
# The Barbecue Chicken Pizza       L        943       943
# The California Chicken Pizza     L        865       865
# The Italian Supreme Pizza        L        723       723
# The Pepper Salami Pizza          L        664       664
# The Prosciutto and Arugula Pizza L        412       412
# The Soppressata Pizza            L        397       397
# The Chicken Pesto Pizza          L        385       385
# The Spinach Supreme Pizza        L        277       277
# The Spinach Pesto Pizza          L        274       274
# The Chicken Alfredo Pizza        L        186       186

# %%
size = df.groupby("size")["sales"].sum().reset_index().sort_values("sales", ascending=False)
size
# Out:
#   size      sales
# 0    L  375318.70
# 1    M  249382.25
# 2    S  178076.50
# 3   XL   14076.00
# 4  XXL    1006.60

# %%
sns.barplot(data=size, x="sales", y="size")
# Out:
# <Axes: xlabel='sales', ylabel='size'>
